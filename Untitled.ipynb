# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/Admin/B-70/BitcoinHeistData.csv")
df
x=df['length']
y=df['weight']
plt.scatter(x,y,color="Orange",marker="^")
b,a=np.polyfit(x,y,1)
y1=a+b*x
y1








plt.plot(x,y1)
plt.show()
